# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshVel/Chicken-Disease/blob/main/FashionDesigning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

categories = [
    "partywear",
    "ethnicwear",
    "westernwear",
    "casualwear",
    "bridalwear",
    "officewear",
    "kidswear",
    "winterwear",
    "maternitywear",
    "nightwear",
    "sportswear",
    "fusionwear",
    "formalwear",
    "streetwear",
    "beachwear"
]

for category in categories:
    os.makedirs(f"fashion_data/{category}", exist_ok=True)

print("✅ All fashion folders created!")
# Out:
# ✅ All fashion folders created!

# %%
from google.colab import files

uploaded = files.upload()  # Select your downloaded fashion image here
# Out:
#      <input type="file" id="files-f016441c-6bf4-49a2-8168-abb7d2dbe873" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f016441c-6bf4-49a2-8168-abb7d2dbe873">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import json

annotation = {
    "image": "partywear/party1.jpg",

    "caption": "Graceful pink floral flared gown perfect for a twirl",

    "paragraph": (
        "This eye-catching gown showcases a beautiful flowy silhouette adorned with oversized magenta floral prints on a soft pink base. "
        "Crafted from light and breathable georgette fabric, the dress features long flared sleeves and a round neckline. "
        "It’s the perfect blend of elegance and comfort for casual celebrations, garden parties, or festive get-togethers."
    ),

    "qa": [
        {
            "question": "What color is the dress?",
            "answer": "The dress is primarily light pink with bold magenta floral prints throughout."
        },
        {
            "question": "What type of design or pattern does the dress have?",
            "answer": "It features a vibrant floral print pattern with large flower motifs."
        },
        {
            "question": "What is the dress made of?",
            "answer": "The gown is made of lightweight georgette fabric, making it ideal for warm weather events."
        },
        {
            "question": "What kind of sleeves does this gown have?",
            "answer": "It comes with full-length flared sleeves that add a graceful, flowing effect to the overall design."
        },
        {
            "question": "On what occasions can this gown be worn?",
            "answer": "This gown is well-suited for casual parties, daytime functions, family celebrations, or even outdoor photo shoots."
        },
        {
            "question": "What is special about the dress's style?",
            "answer": "The gown's flowing structure and vibrant floral design give it a fairy-tale charm that stands out effortlessly in any crowd."
        }
    ]
}

# Append to JSONL
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Enhanced annotation with rich captions, paragraph, and full-sentence Q&A saved.")
# Out:
# ✅ Enhanced annotation with rich captions, paragraph, and full-sentence Q&A saved.

# %%
import json

annotation = {
    "image": "partywear/party2.jpg",

    "caption": "Elegant embroidered purple georgette saree with blouse",

    "paragraph": (
        "This exquisite purple saree is crafted from premium georgette fabric, offering a soft and lightweight drape. "
        "Adorned with delicate embroidery work throughout, it comes with a stylish matching blouse that enhances its festive charm. "
        "Perfect for weddings, festive events, or glamorous evening parties, this saree adds a royal touch to any occasion."
    ),

    "qa": [
        {
            "question": "What color is the saree?",
            "answer": "The saree is a deep, elegant shade of purple."
        },
        {
            "question": "What fabric is used in this saree?",
            "answer": "It is made from soft and flowing georgette fabric."
        },
        {
            "question": "Does this saree come with a blouse?",
            "answer": "Yes, it comes with a matching embroidered blouse."
        },
        {
            "question": "What type of design is featured on the saree?",
            "answer": "The saree features intricate and delicate embroidery work."
        },
        {
            "question": "Which occasions is this saree suitable for?",
            "answer": "It is ideal for weddings, festive celebrations, and stylish evening parties."
        },
        {
            "question": "What makes this saree stand out?",
            "answer": "The rich purple color, detailed embroidery, and lightweight fabric make it both elegant and comfortable to wear."
        }
    ]
}

# ✅ Append this to the existing JSONL file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party2.jpg saved successfully.")
# Out:
# ✅ Annotation for party2.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party3.jpg",

    "caption": "Chic maroon embellished 3-piece party ensemble with shrug",

    "paragraph": (
        "This elegant 3-piece maroon set includes a sleeveless crop top, a flowy sharara-style bottom, and a matching sheer shrug. "
        "Decorated with mirror-style embellishments, the outfit radiates festive energy and glam. "
        "It’s crafted from soft georgette and is perfect for sangeets, receptions, or evening parties where a touch of modern tradition is desired."
    ),

    "qa": [
        {
            "question": "What color is the outfit?",
            "answer": "The outfit is a rich maroon shade, suitable for festive and evening events."
        },
        {
            "question": "What pieces are included in this dress set?",
            "answer": "It includes a crop top, a sharara-style palazzo bottom, and a matching sheer shrug."
        },
        {
            "question": "What kind of embellishments are on this dress?",
            "answer": "The dress features mirror-style embellishments on the top and shrug."
        },
        {
            "question": "What is the material used in this outfit?",
            "answer": "The ensemble is made from soft georgette fabric, providing a graceful flow."
        },
        {
            "question": "Is this suitable for traditional events?",
            "answer": "Yes, it's perfect for weddings, sangeets, mehendi functions, or any celebratory event."
        },
        {
            "question": "What makes this outfit stand out?",
            "answer": "The combination of elegant layering, rich maroon color, and mirror embellishments give it a stylish Indo-western flair."
        }
    ]
}

# Append to the existing annotation file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party3.jpg saved successfully.")
# Out:
# ✅ Annotation for party3.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party4.jpg",

    "caption": "Elegant plum off-shoulder bodycon gown with frill neckline and side slit",

    "paragraph": (
        "This stunning plum-colored evening gown features an off-shoulder design with dramatic layered frills along the neckline. "
        "The body-hugging silhouette flatters the figure, while the thigh-high side slit adds a bold, modern touch. "
        "Perfect for cocktail parties, evening receptions, or red-carpet events, this gown radiates elegance and confidence."
    ),

    "qa": [
        {
            "question": "What is the color of the gown?",
            "answer": "The gown is a rich plum color, perfect for evening events."
        },
        {
            "question": "What kind of neckline does this gown have?",
            "answer": "It has an off-shoulder neckline with dramatic layered frills."
        },
        {
            "question": "Does the gown have a slit?",
            "answer": "Yes, it features a stylish thigh-high side slit for added flair."
        },
        {
            "question": "Is this gown suitable for traditional functions?",
            "answer": "No, it is more suitable for western-style events like cocktail parties, formal dinners, or evening receptions."
        },
        {
            "question": "What type of silhouette does the gown have?",
            "answer": "It has a bodycon silhouette that fits closely to the body, enhancing curves."
        },
        {
            "question": "What kind of accessories would suit this gown?",
            "answer": "Minimalist jewelry like studs, a clutch, and heels would complement this gown perfectly."
        }
    ]
}

# Append this to your existing JSONL file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party4.jpg saved successfully.")
# Out:
# ✅ Annotation for party4.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party5.jpg",

    "caption": "Navy blue formal 3-piece suit set for boys with red tie and pocket square",

    "paragraph": (
        "This stylish 3-piece navy blue suit is tailored for boys, featuring a double-breasted blazer, matching trousers, and a crisp white shirt. "
        "It’s elegantly paired with a bold red tie and pocket square, adding a dash of festive charm. "
        "Ideal for weddings, birthday parties, or formal events, this outfit ensures young boys look dapper and confident."
    ),

    "qa": [
        {
            "question": "What color is the suit?",
            "answer": "The suit is a dark navy blue color."
        },
        {
            "question": "How many pieces are included in the outfit?",
            "answer": "It is a 3-piece set including blazer, trousers, and a shirt."
        },
        {
            "question": "What accessories are included with the outfit?",
            "answer": "The outfit comes with a red tie and a matching pocket square."
        },
        {
            "question": "Is this outfit suitable for weddings?",
            "answer": "Yes, it is perfect for weddings, receptions, or any formal celebration."
        },
        {
            "question": "What kind of blazer does the outfit have?",
            "answer": "It has a double-breasted blazer with a golden crest embroidery on the pocket."
        },
        {
            "question": "Can this be worn casually?",
            "answer": "No, it is best suited for formal or special events rather than casual wear."
        }
    ]
}

# Append to your existing JSONL file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party5.jpg saved successfully.")
# Out:
# ✅ Annotation for party5.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party6.jpg",

    "caption": "White floral printed festive kurta set for men with lotus and cow motifs",

    "paragraph": (
        "This elegant white kurta set features vibrant lotus flower prints and traditional cow motifs, giving it a perfect ethnic yet contemporary vibe. "
        "The design includes full sleeves, a mandarin collar, and a comfortable straight fit. "
        "Made from breathable cotton blend fabric, this kurta set is perfect for weddings, festive celebrations, or pooja functions, offering both comfort and cultural richness."
    ),

    "qa": [
        {
            "question": "What color is the kurta?",
            "answer": "The kurta is primarily white with colorful prints."
        },
        {
            "question": "What motifs are featured on this outfit?",
            "answer": "It has lotus flower prints along with traditional cow motifs."
        },
        {
            "question": "What type of event is this outfit suitable for?",
            "answer": "This kurta set is perfect for weddings, poojas, and festive celebrations."
        },
        {
            "question": "What type of collar does this kurta have?",
            "answer": "It features a mandarin collar, also known as a Chinese collar."
        },
        {
            "question": "What material is this kurta made from?",
            "answer": "It is made from a soft and breathable cotton-blend fabric."
        },
        {
            "question": "Is this kurta casual or partywear?",
            "answer": "Though it’s ethnic, the vibrant design makes it well-suited for festive partywear."
        }
    ]
}

# Append to the JSONL dataset
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party6.jpg saved successfully.")
# Out:
# ✅ Annotation for party6.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party7.jpg",

    "caption": "Black embroidered ethnic partywear kurta for men with silver threadwork",

    "paragraph": (
        "This stunning black kurta for men features intricate silver embroidery along the chest and shoulders, exuding royal elegance. "
        "The kurta is tailored in a straight-fit style with a mandarin collar and full sleeves. "
        "Crafted for celebrations, it’s the perfect choice for evening parties, wedding receptions, or traditional functions where bold ethnic fashion is admired."
    ),

    "qa": [
        {
            "question": "What color is the kurta?",
            "answer": "The kurta is black with rich silver embroidery."
        },
        {
            "question": "What events is this kurta best suited for?",
            "answer": "It’s ideal for receptions, cultural ceremonies, or any grand evening parties."
        },
        {
            "question": "What type of embroidery is featured?",
            "answer": "The kurta showcases intricate floral and leaf motifs in silver thread embroidery."
        },
        {
            "question": "Is this suitable for casual wear?",
            "answer": "No, it is too grand and embellished for casual occasions. It is best suited for special events."
        },
        {
            "question": "What kind of fit and collar does this kurta have?",
            "answer": "It has a straight fit and a mandarin-style collar."
        },
        {
            "question": "What makes this outfit stand out?",
            "answer": "The bold contrast of black fabric with rich silver embroidery gives it a luxurious, royal look."
        }
    ]
}

# Append to JSONL file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party7.jpg saved successfully.")
# Out:
# ✅ Annotation for party7.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party8.jpg",

    "caption": "Men’s floral embroidered cotton blend kurta set with straight pajama",

    "paragraph": (
        "This elegant men's kurta set features intricate floral embroidery on a cotton blend fabric, offering both style and comfort. "
        "The top has a long-sleeved, straight-fit design with a traditional stitched finish, paired with a matching straight pajama bottom. "
        "Available in sizes M to XXL, it is designed to fit various body types with chest sizes ranging from 38 to 44 inches. "
        "Ideal for festive occasions, weddings, and cultural events, this kurta set blends classic Indian design with modern embroidery patterns."
    ),

    "qa": [
        {
            "question": "What type of embroidery is featured on this kurta?",
            "answer": "The kurta features elegant floral embroidery, often described as Chikankari or Schiffli-style."
        },
        {
            "question": "What material is the outfit made from?",
            "answer": "Both the kurta and pajama are made from a cotton blend fabric."
        },
        {
            "question": "What sizes are available for this kurta set?",
            "answer": "Sizes M, L, XL, and XXL are available with chest sizes from 38 to 44 inches."
        },
        {
            "question": "What kind of bottom is included in the set?",
            "answer": "It comes with a straight pajama stitched from the same cotton blend material."
        },
        {
            "question": "Is this outfit stitched or unstitched?",
            "answer": "The kurta set is fully stitched and ready to wear."
        },
        {
            "question": "What occasions is this outfit best suited for?",
            "answer": "It is perfect for weddings, festivals, poojas, and other traditional celebrations."
        }
    ]
}

# Append the annotation to the dataset
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party9.jpg saved successfully.")
# Out:
# ✅ Annotation for party9.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party9.jpg",

    "caption": "Bluish silk kurta with balloon-style dhoti pants for men",

    "paragraph": (
        "This outfit features a bluish silk kurta paired with balloon-style dhoti pants, giving it a rich ethnic flair suitable for grand occasions. "
        "The kurta is designed with a straight silhouette and full sleeves, creating a traditional yet sleek appearance. "
        "The matching balloon pants add volume and cultural depth to the attire, making it ideal for weddings, festive events, and cultural celebrations. "
        "Made from smooth Dupion silk, the ensemble offers a luxurious feel and elegant drape."
    ),

    "qa": [
        {
            "question": "What type of outfit is this?",
            "answer": "It is a traditional men's kurta and dhoti pant set."
        },
        {
            "question": "What fabric is used for this outfit?",
            "answer": "The entire set is made from Dupion silk."
        },
        {
            "question": "What color is the kurta set?",
            "answer": "The outfit is blue in color."
        },
        {
            "question": "What type of bottom is paired with the kurta?",
            "answer": "It is paired with balloon-style dhoti pants."
        },
        {
            "question": "What type of sleeves does the kurta have?",
            "answer": "The kurta has long sleeves."
        },
        {
            "question": "Is this outfit suitable for formal events?",
            "answer": "Yes, it is suitable for weddings, festive occasions, and cultural celebrations."
        }
    ]
}

# Append to the dataset file
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party10.jpg saved successfully.")
# Out:
# ✅ Annotation for party10.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party10.jpg",

    "caption": "Pink satin silk lehenga choli with sleeveless blouse for girls and women",

    "paragraph": (
        "This elegant partywear set includes a flowing flower printing lehenga skirt and a matching sleeveless choli, both made from smooth satin silk fabric. "
        "The ashthetic color gives it a clean, graceful look suitable for festive functions and evening parties. "
        "Its lightweight drape and shiny texture make it ideal for young girls or women attending weddings, cultural ceremonies, or family gatherings."
    ),

    "qa": [
        {
            "question": "What type of dress is this?",
            "answer": "It is a lehenga choli set made for girls and women."
        },
        {
            "question": "What fabric is used in this outfit?",
            "answer": "It is made from satin silk, giving it a shiny and soft appearance."
        },
        {
            "question": "What is the sleeve style of the choli?",
            "answer": "The choli is sleeveless."
        },
        {
            "question": "Is this suitable for formal or casual events?",
            "answer": "It is best suited for formal events like weddings, poojas, or festive celebrations."
        },
        {
            "question": "What is the primary color of this lehenga set?",
            "answer": "It is a soft, elegant asthetic."
        },
        {
            "question": "Is this outfit heavy or lightweight?",
            "answer": "It is lightweight and flowy, making it comfortable to wear for long hours."
        }
    ]
}

# Append the new entry to your dataset
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party11.jpg saved successfully.")
# Out:
# ✅ Annotation for party11.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party11.jpg",

    "caption": "Printed full-length georgette Anarkali gown with matching dupatta for women",

    "paragraph": (
        "This elegant partywear gown is crafted from lightweight georgette fabric with a soft printed design. "
        "It features a full-length flared Anarkali cut that adds grace and flow with every step. "
        "The long sleeves and round neckline create a modest yet stylish silhouette. "
        "Paired with a matching dupatta, this gown is perfect for festive events, weddings, and traditional gatherings. "
        "No bottomwear is included, making it a complete gown-dupatta set."
    ),

    "qa": [
        {
            "question": "What type of dress is this?",
            "answer": "It is a georgette Anarkali gown with a dupatta."
        },
        {
            "question": "Does the set include bottomwear?",
            "answer": "No, it is a gown and dupatta set only, without bottomwear."
        },
        {
            "question": "What is the fabric used?",
            "answer": "The gown is made from printed georgette fabric."
        },
        {
            "question": "What occasions is this outfit suitable for?",
            "answer": "It is ideal for weddings, festivals, Eid celebrations, and party functions."
        },
        {
            "question": "What is the sleeve length of this gown?",
            "answer": "It features full-length sleeves."
        },
        {
            "question": "Is the gown plain or printed?",
            "answer": "The gown has a printed design."
        }
    ]
}

# Append the annotation to the dataset
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party12.jpg saved successfully.")
# Out:
# ✅ Annotation for party12.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party12.jpg",

    "caption": "Printed full-length georgette Anarkali gown with matching dupatta for women",

    "paragraph": (
        "This elegant partywear gown is crafted from lightweight georgette fabric with a soft printed design. "
        "It features a full-length flared Anarkali cut that adds grace and flow with every step. "
        "The long sleeves and round neckline create a modest yet stylish silhouette. "
        "Paired with a matching dupatta, this gown is perfect for festive events, weddings, and traditional gatherings. "
        "No bottomwear is included, making it a complete gown-dupatta set."
    ),

    "qa": [
        {
            "question": "What type of dress is this?",
            "answer": "It is a georgette Anarkali gown with a dupatta."
        },
        {
            "question": "Does the set include bottomwear?",
            "answer": "No, it is a gown and dupatta set only, without bottomwear."
        },
        {
            "question": "What is the fabric used?",
            "answer": "The gown is made from printed georgette fabric."
        },
        {
            "question": "What occasions is this outfit suitable for?",
            "answer": "It is ideal for weddings, festivals, Eid celebrations, and party functions."
        },
        {
            "question": "What is the sleeve length of this gown?",
            "answer": "It features full-length sleeves."
        },
        {
            "question": "Is the gown plain or printed?",
            "answer": "The gown has a printed design."
        }
    ]
}

# Append the annotation to the dataset
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Annotation for party12.jpg saved successfully.")
# Out:
# ✅ Annotation for party12.jpg saved successfully.

# %%
import json

annotation = {
    "image": "partywear/party13.jpg",

    "caption": "Navy blue open shirt layered over a white T-shirt for men – party casual look",

    "paragraph": (
        "This modern outfit features a full-sleeve, solid navy blue cotton blend shirt worn open over a plain white round-neck T-shirt. "
        "The combination creates a relaxed yet stylish look, perfect for parties, outings, or casual evening events. "
        "The open shirt adds dimension and layering, while the white T-shirt provides a clean contrast that highlights the outfit. "
        "This ensemble is trendy, breathable, and suitable for semi-formal to casual occasions."
    ),

    "qa": [
        {
            "question": "What type of outfit is this?",
            "answer": "It is a layered outfit with an open shirt over a T-shirt."
        },
        {
            "question": "What are the main colors in this outfit?",
            "answer": "Navy blue for the shirt and white for the inner T-shirt."
        },
        {
            "question": "What sleeve type does the outer shirt have?",
            "answer": "It has long sleeves."
        },
        {
            "question": "Is the shirt buttoned or open?",
            "answer": "The shirt is worn open over the T-shirt."
        },
        {
            "question": "What type of event is this outfit suitable for?",
            "answer": "It is suitable for parties, casual gatherings, and outings."
        },
        {
            "question": "Is this look formal or casual?",
            "answer": "This is a casual partywear look."
        }
    ]
}

# Append the corrected annotation
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Final layered outfit annotation for party13.jpg saved.")
# Out:
# ✅ Final layered outfit annotation for party13.jpg saved.

# %%
import json

annotation = {
    "image": "partywear/party14.jpg",

    "caption": "Black open solid shirt layered over a white T-shirt – casual partywear for men",

    "paragraph": (
        "This outfit features a stylish black full-sleeve solid shirt worn open over a plain white round-neck T-shirt. "
        "Crafted from a soft cotton blend, this combo offers a relaxed and modern vibe perfect for partywear. "
        "The open layering adds depth to the look, while the crisp contrast with the inner tee keeps it youthful and trendy. "
        "Ideal for outings, club nights, or stylish casual events."
    ),

    "qa": [
        {
            "question": "What type of outfit is this?",
            "answer": "A black open shirt layered over a white T-shirt for men."
        },
        {
            "question": "What is the sleeve length of the shirt?",
            "answer": "The shirt has long sleeves."
        },
        {
            "question": "What color is the outer shirt?",
            "answer": "The outer shirt is solid black."
        },
        {
            "question": "What color is the inner T-shirt?",
            "answer": "The inner T-shirt is white."
        },
        {
            "question": "Is this suitable for partywear?",
            "answer": "Yes, it's perfect for casual parties and stylish outings."
        },
        {
            "question": "What fabric is the shirt made from?",
            "answer": "The shirt is made from a breathable cotton blend."
        }
    ]
}

with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Corrected annotation for party14.jpg saved successfully.")
# Out:
# ✅ Corrected annotation for party14.jpg saved successfully.

# %%
import json

annotation = {
    "image": "beachwear/beach1.jpg",

    "caption": "Pink sleeveless lycra swimsuit for women – beachwear bodysuit",

    "paragraph": (
        "This stylish beachwear piece features a soft pink lycra swimsuit designed in a bodysuit style. "
        "Its sleeveless cut and snug fit offer freedom of movement, making it ideal for beach outings, vacations, or poolside lounging. "
        "The solid pink tone adds a feminine and vibrant vibe, while the stretchy, breathable lycra ensures all-day comfort. "
        "Perfect for women who want to blend elegance and comfort in their swimwear."
    ),

    "qa": [
        {
            "question": "What color is this swimsuit?",
            "answer": "The swimsuit is pink."
        },
        {
            "question": "What fabric is used in this outfit?",
            "answer": "It is made from soft, stretchable lycra."
        },
        {
            "question": "What type of clothing is this?",
            "answer": "It is a women's swimsuit bodysuit."
        },
        {
            "question": "Is this outfit sleeveless?",
            "answer": "Yes, it is sleeveless."
        },
        {
            "question": "Where can this be worn?",
            "answer": "It is suitable for beaches, pools, and vacation wear."
        },
        {
            "question": "Is this swimsuit suitable for active swimming?",
            "answer": "Yes, its lycra fabric offers flexibility and comfort."
        }
    ]
}

# Save the corrected annotation
with open("fashion_data/fashion_vqa_data.jsonl", "a") as f:
    f.write(json.dumps(annotation) + "\n")

print("✅ Corrected annotation for beachwear1.jpg (pink) saved successfully.")
# Out:
# ✅ Corrected annotation for beachwear1.jpg (pink) saved successfully.

# %%
from transformers import AutoProcessor, AutoModelForVisualQuestionAnswering

processor = AutoProcessor.from_pretrained("yanka9/vilt_finetuned_deepfashionVQA_v2")
model = AutoModelForVisualQuestionAnswering.from_pretrained("yanka9/vilt_finetuned_deepfashionVQA_v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]

# %%
from torch.utils.data import Dataset
from PIL import Image

class FashionVQADataset(Dataset):
    def __init__(self, json_data, processor):
        self.data = json_data
        self.processor = processor

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image = Image.open(item['image_path']).convert("RGB")
        question = item['question']
        answer = item['answer']

        encoding = self.processor(images=image,
                                  text=question,
                                  return_tensors="pt",
                                  padding="max_length",
                                  truncation=True)

        # Flatten batch dimension
        for k in encoding:
            encoding[k] = encoding[k].squeeze(0)

        # Set labels
        encoding["labels"] = self.processor.tokenizer(answer, return_tensors="pt", padding="max_length", truncation=True)["input_ids"].squeeze(0)

        return encoding

# %%
import json

json_data = []
with open("fashion_data/fashion_vqa_data.jsonl", "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue  # skip empty lines
        json_data.append(json.loads(line))

# %%
def __getitem__(self, idx):
    item = self.data[idx]
    image_path = os.path.join(self.image_root, item["image"])
    image = Image.open(image_path).convert("RGB")

    encoding = self.processor(image, item["question"], return_tensors="pt")
    encoding = {k: v.squeeze(0) for k, v in encoding.items()}

    answer_tokens = self.processor.tokenizer.encode(item["answer"], add_special_tokens=False)
    encoding["labels"] = torch.tensor(answer_tokens)

    return encoding

# %%
dataset = FashionVQADataset(json_data, processor, image_root="/content/fashion_data/partywear")

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./vqa_fashion_output",
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir="./logs",
    logging_steps=10,
    save_steps=100,
    save_total_limit=2,
    remove_unused_columns=False,
    fp16=True,  # If you're using a GPU with mixed precision support
    report_to="none"  # or "wandb" if using Weights & Biases
)

# %%
from transformers import DefaultDataCollator

data_collator = DefaultDataCollator(return_tensors="pt")

# %%
from transformers import ViltForQuestionAnswering

model = ViltForQuestionAnswering.from_pretrained("yanka9/vilt_finetuned_deepfashionVQA_v2")

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    data_collator=data_collator,
    tokenizer=processor.tokenizer
)
# Out:
# /tmp/ipython-input-72-3821092659.py:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# !ls fashion_data/partywear/
# Out:
# party10.jpg  party13.jpg  party2.jpg  party5.jpg  party8.jpg
# party11.jpg  party14.jpg  party3.jpg  party6.jpg  party9.jpg
# party12.jpg  party1.jpg   party4.jpg  party7.jpg

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-73-49973641.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2204                 hf_hub_utils.enable_progress_bars()
#    2205         else:
# -> 2206             return inner_training_loop(
#    2207                 args=args,
#    2208                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2500                 update_step += 1
#    2501                 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# ...

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-75-4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2204                 hf_hub_utils.enable_progress_bars()
#    2205         else:
# -> 2206             return inner_training_loop(
#    2207                 args=args,
#    2208                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2500                 update_step += 1
#    2501                 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# ...

# %%
import json
from datasets import Dataset

# Load JSON file
with open("/content/fashion_data/data.json") as f:
    data = json.load(f)


# Convert to Hugging Face Dataset
dataset = Dataset.from_list(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-79-1190036497.py in <cell line: 0>()
#       3
#       4 # Load JSON file
# ----> 5 with open("/content/fashion_data/data.json") as f:
#       6     data = json.load(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/fashion_data/data.json'
